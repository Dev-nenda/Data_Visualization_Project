# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./data/연도별_고령인구_통계.csv', 
                  encoding='cp949',
                  low_memory=False)

# %%
data.head()
# Out:
#                                          가정별         인구구조,부양비별        2010  \
# 0  중위 추계(기본 추계: 출산율-중위 / 기대수명-중위 / 국제순이동-중위)            총인구(명)  49554112.0
# 1  중위 추계(기본 추계: 출산율-중위 / 기대수명-중위 / 국제순이동-중위)     인구(명): 65세 이상   5366109.0
# 2  중위 추계(기본 추계: 출산율-중위 / 기대수명-중위 / 국제순이동-중위)  - 구성비(%): 65세 이상        10.8
#
#          2011        2012        2013        2014        2015        2016  \
# 0  49936638.0  50199853.0  50428893.0  50746659.0  51014947.0  51217803.0
# 1   5515179.0   5766729.0   6022659.0   6277126.0   6541168.0   6757083.0
# 2        11.0        11.5        11.9        12.4        12.8        13.2
#
#          2017        2018        2019        2020        2021        2022  \
# 0  51361911.0  51585058.0  51764822.0  51836239.0  51744876.0  51628117.0
# 1   7066060.0   7366085.0   7688994.0   8151867.0   8571347.0   9018412.0
# 2        13.8        14.3        14.9        15.7        16.6        17.5
#
#          2023
# 0  51558034.0
# 1   9499933.0
# 2        18.4

# %%
data.set_index('인구구조,부양비별', inplace=True)

# %%
data.drop(columns={'가정별'}, inplace=True)

# %%
data
# Out:
#                         2010        2011        2012        2013        2014  \
# 인구구조,부양비별
# 총인구(명)            49554112.0  49936638.0  50199853.0  50428893.0  50746659.0
# 인구(명): 65세 이상      5366109.0   5515179.0   5766729.0   6022659.0   6277126.0
# - 구성비(%): 65세 이상        10.8        11.0        11.5        11.9        12.4
#
#                         2015        2016        2017        2018        2019  \
# 인구구조,부양비별
# 총인구(명)            51014947.0  51217803.0  51361911.0  51585058.0  51764822.0
# 인구(명): 65세 이상      6541168.0   6757083.0   7066060.0   7366085.0   7688994.0
# - 구성비(%): 65세 이상        12.8        13.2        13.8        14.3        14.9
#
#                         2020        2021        2022        2023
# 인구구조,부양비별
# 총인구(명)            51836239.0  51744876.0  51628117.0  51558034.0
# 인구(명): 65세 이상      8151867.0   8571347.0   9018412.0   9499933.0
# - 구성비(%): 65세 이상        15.7        16.6        17.5        18.4

# %%
data.index.name = ''
# Out:
# ''

# %%
data.rename(index={'총인구(명)':'총 인구', '인구(명): 65세 이상': '고령 인구', '- 구성비(%): 65세 이상': '비율'}, inplace=True)

# %%
data.astype(float)
# Out:
#              2010        2011        2012        2013        2014        2015  \
#
# 총 인구   49554112.0  49936638.0  50199853.0  50428893.0  50746659.0  51014947.0
# 고령 인구   5366109.0   5515179.0   5766729.0   6022659.0   6277126.0   6541168.0
# 비율           10.8        11.0        11.5        11.9        12.4        12.8
#
#              2016        2017        2018        2019        2020        2021  \
#
# 총 인구   51217803.0  51361911.0  51585058.0  51764822.0  51836239.0  51744876.0
# 고령 인구   6757083.0   7066060.0   7366085.0   7688994.0   8151867.0   8571347.0
# 비율           13.2        13.8        14.3        14.9        15.7        16.6
#
#              2022        2023
#
# 총 인구   51628117.0  51558034.0
# 고령 인구   9018412.0   9499933.0
# 비율           17.5        18.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 총 인구 to 비율
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2010    3 non-null      float64
#  1   2011    3 non-null      float64
#  2   2012    3 non-null      float64
#  3   2013    3 non-null      float64
#  4   2014    3 non-null      float64
#  5   2015    3 non-null      float64
#  6   2016    3 non-null      float64
#  7   2017    3 non-null      float64
#  8   2018    3 non-null      float64
#  9   2019    3 non-null      float64
#  10  2020    3 non-null      float64
#  11  2021    3 non-null      float64
#  12  2022    3 non-null      float64
#  13  2023    3 non-null      float64
# dtypes: float64(14)
# memory usage: 360.0+ bytes

# %%
data.to_csv('./data/고령인구통계_data.csv')
