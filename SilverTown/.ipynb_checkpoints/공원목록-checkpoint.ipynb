# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./data/전국도시공원정보표준데이터.csv', 
                  encoding='cp949',
                  low_memory=False)

# %%
data.head()
data.tail()
# Out:
#               관리번호  공원명   공원구분 소재지도로명주소               소재지지번주소         위도  \
# 18059  11500-00044  꿈돌이  어린이공원      NaN  서울특별시 강서구 화곡동 24-128  37.546097
# 18060  11500-00045  소나무  어린이공원      NaN   서울특별시 강서구 화곡동 29-31  37.547058
# 18061  11500-00046   산새  어린이공원      NaN     서울특별시 강서구 화곡동 772  37.546268
# 18062  11500-00047   박장  어린이공원      NaN   서울특별시 강서구 화곡동 56-25  37.540768
# 18063  11500-00048   참새  어린이공원      NaN  서울특별시 강서구 화곡동 56-638  37.539725
#
#                경도    공원면적 공원보유시설(운동시설) 공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설)  \
# 18059  126.845352  1507.0          NaN      어린이놀이시설          화장실          NaN
# 18060  126.847807   942.0          NaN      어린이놀이시설          NaN          NaN
# 18061  126.850385   539.0          NaN      어린이놀이시설          음수대          NaN
# 18062  126.849087   929.0          NaN      어린이놀이시설          NaN          NaN
# 18063  126.847003   256.0          NaN      어린이놀이시설          NaN          NaN
#
# ...
